# %%
import sklearn
print(sklearn.__version__)
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pickle
# Out:
# 1.6.1

# %% [markdown]
# ## Read Dataset

# %%
preprocessed_df = pd.read_pickle("idealize_1.pkl")

# %% [markdown]
# ##  Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
x = preprocessed_df.drop(columns=["RainTomorrow"])
y = preprocessed_df["RainTomorrow"]

# %%
preprocessed_df.shape
# Out:
# (113754, 20)

# %%
preprocessed_df.sample(5)
# Out:
#         Location   MinTemp   MaxTemp  Rainfall  WindGustDir  WindGustSpeed  \
# 33642  -1.266628  1.318400  1.923685 -0.277685    -0.659159  -3.775571e-01
# 63550   1.644151 -0.465103 -0.902549 -0.254160     1.379883   1.604096e+00
# 106115  0.180396  0.254556  0.475416 -0.160060     0.956596   2.321823e-01
# 76918   0.512371  2.272731  1.473738 -0.277685     1.301793  -7.586442e-01
# 5727    0.282799 -0.777998 -0.424479 -0.277685     0.956596  -5.415574e-16
#
#         WindDir9am  WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  \
# 33642     0.574642   -1.371700      0.342057     -0.417345    -0.994959
# 63550     0.574642    1.461288      0.908731     -0.417345    -0.994959
# 106115    1.761797    1.574738     -0.564621      0.041622     0.695128
# 76918     1.093460    1.390112     -0.111282      0.385847     0.272606
# 5727      1.165612    1.574738     -0.904625      1.074297    -0.308361
#
#         Humidity3pm   Pressure9am  Pressure3pm   Temp9am   Temp3pm  \
# 33642     -1.290426 -2.907191e-01    -0.533415  1.392768  1.938134
# 63550      0.413574 -6.911065e-01    -1.087384 -0.490470 -0.782056
# 106115    -1.144368 -2.233339e+00    -2.180350  0.343095  0.527127
# 76918      0.608317 -1.121152e+00    -1.252077  2.071969  1.618112
# 5727      -0.657511 -1.685880e-14     0.000000 -0.397851 -0.331115
#
#         RainTomorrow      Year     Month  RainToday_Yes
# 33642              0 -1.085800  1.634134      -0.532569
# 63550              1 -0.299239 -0.118965      -0.532569
# 106115             0 -0.692519  1.634134      -0.532569
# 76918              0  0.487322 -1.579881      -0.532569
# 5727               1 -1.085800  0.465401      -0.532569

# %% [markdown]
# ## Try ML Models

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
import xgboost as xgb
import lightgbm as lgb


# Train-test split
# Define models
models = {
    #"Logistic Regression": LogisticRegression(max_iter=1000),
    #"Naive Bayes": GaussianNB(),
    #"K-Nearest Neighbors": KNeighborsClassifier(),
#     "SVM (RBF Kernel)": SVC(kernel='rbf', probability=True),
#     "Decision Tree": DecisionTreeClassifier(),
#     "Random Forest": RandomForestClassifier(),
    "AdaBoost": AdaBoostClassifier(),
#     "Gradient Boosting": GradientBoostingClassifier(),
#     "XGBoost": xgb.XGBClassifier(use_label_encoder=False, eval_metric='logloss'),
#     "LightGBM": lgb.LGBMClassifier()
 }

# Train and evaluate each model
for name, model in models.items():
    model.fit(x,y)     
    preds = model.predict(x)
   
print("Done")
# Out:
# Done

# %%
import joblib

# Train KNN model
knn_model = AdaBoostClassifier()
knn_model.fit(x,y)

# Save the model to a file
joblib_file = "knn_model.joblib"
joblib.dump(knn_model, joblib_file)

print(f"KNN model saved to {joblib_file}")
# Out:
# KNN model saved to knn_model.joblib

# %%
import pandas as pd
import joblib

# Load test data
test_df = pd.read_pickle("idealize_1_test.pkl")

# %%
test_df.sample(5)
# Out:
#              id  Location   MinTemp   MaxTemp  Rainfall  WindGustDir  \
# 21813  0.925011 -0.515290 -2.186200 -1.374467 -0.284728     1.074265
# 10960 -0.396973  0.492389  0.777788 -0.177250  0.134936    -0.114584
# 3686  -1.283005  0.000676  1.734419  1.259410  0.208994    -0.665808
# 15754  0.186975  0.013554 -0.586587  0.090363 -0.284728     1.074265
# 18361  0.504529 -0.485268  0.338679  0.231212 -0.136612    -1.397140
#
#        WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  ...  Humidity9am  \
# 21813      -1.219332    1.317448    0.571494     -1.571645  ...     1.645236
# 10960       1.430307   -0.177461   -0.151725      2.111274  ...     0.007130
# 3686       -0.537996   -0.590009   -0.831701     -0.344005  ...     0.218498
# 15754       0.446155    0.791347    1.430116     -0.567212  ...     0.852604
# 18361      -1.067924   -0.590009   -0.844527     -0.120798  ...    -0.045713
#
#        Humidity3pm  Pressure9am  Pressure3pm   Temp9am   Temp3pm      Year  \
# 21813     0.371113    -0.166796    -0.140489 -2.501375 -1.317358 -0.991863
# 10960     1.054039     0.691551     1.069823  0.305836 -0.208753  0.259250
# 3686      0.175992    -0.270390    -0.439331  1.546592  1.235350 -0.764388
# 15754    -0.506934     1.816282     1.787046 -0.934920  0.185093 -0.650650
# 18361     0.029651     1.135524     1.024997  0.538477  0.360136  0.145512
#
#           Month  Day RainToday_Yes
# 21813  0.178924   14     -0.534535
# 10960 -0.983083   12      1.870786
# 3686  -1.273585   17      1.870786
# 15754  1.050430   10     -0.534535
# 18361 -1.564087   16      1.870786
#
# [5 rows x 21 columns]

# %%
import pandas as pd
import joblib

# Load test data
test_df = pd.read_pickle("idealize_1_test.pkl")

# Save ID column for final output
test_ids = test_df['id']

# Drop unused columns for prediction
X_new = test_df.drop(['id','Day'], axis=1)

# Load trained model
model = joblib.load("knn_model.joblib")

# Predict
predictions = model.predict(X_new)

# Prepare submission DataFrame
submission_df = pd.DataFrame({
    'id': test_ids,
    'RainTomorrow': predictions
})

# Save to Excel (or CSV depending on submission format)
submission_df.to_csv("submission_file.csv", index=False)

print("🎉 Submission file created successfully!")
# Out:
# 🎉 Submission file created successfully!

# %%
from sklearn.linear_model import LogisticRegression

# L2 Regularized Logistic Regression (Ridge)
log_reg_l2 = LogisticRegression(penalty='l2', C=1.0, solver='liblinear', max_iter=1000)

# L1 Regularized Logistic Regression (Lasso)
log_reg_l1 = LogisticRegression(penalty='l1', C=1.0, solver='liblinear', max_iter=1000)

# Fit and evaluate both
for name, model in {
    "Logistic Regression (L2)": log_reg_l2,
    "Logistic Regression (L1)": log_reg_l1
}.items():
    model.fit(X_train, y_train)
    preds = model.predict(X_test)
    acc = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds, average='weighted')
    print(f"{name}: Accuracy = {acc:.4f}, F1 Score = {f1:.4f}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[233], line 15
#      10 for name, model in {
#      11     "Logistic Regression (L2)": log_reg_l2,
#      12     "Logistic Regression (L1)": log_reg_l1
#      13 }.items():
#      14     model.fit(X_train, y_train)
# ---> 15     preds = model.predict(X_test)
#      16     acc = accuracy_score(y_test, preds)
#      17     f1 = f1_score(y_test, preds, average='weighted')
#
# File d:\MY PROJECTS\PANDAS_1\pandalearning\Lib\site-packages\sklearn\linear_model\_base.py:374, in LinearClassifierMixin.predict(self, X)
#     360 """
#     361 Predict class labels for samples in X.
#     362
#    (...)    371     Vector containing the class labels for each sample.
#     372 """
#     373 xp, _ = get_namespace(X)
# --> 374 scores = self.decision_function(X)
#     375 if len(scores.shape) == 1:
#     376     indices = xp.astype(scores > 0, indexing_dtype(xp))
#
# File d:\MY PROJECTS\PANDAS_1\pandalearning\Lib\site-packages\sklearn\linear_model\_base.py:351, in LinearClassifierMixin.decision_function(self, X)
#     348 check_is_fitted(self)
#     349 xp, _ = get_namespace(X)
# --> 351 X = validate_data(self, X, accept_sparse="csr", reset=False)
#     352 scores = safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     353 return (
#     354     xp.reshape(scores, (-1,))
#     355     if (scores.ndim > 1 and scores.shape[1] == 1)
#     356     else scores
#     357 )
#
# File d:\MY PROJECTS\PANDAS_1\pandalearning\Lib\site-packages\sklearn\utils\validation.py:2919, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2835 def validate_data(
#    2836     _estimator,
#    2837     /,
#    (...)   2843     **check_params,
#    2844 ):
#    2845     """Validate input data and set or check feature names and counts of the input.
#    2846
#    2847     This helper function should be used in an estimator that requires input
#    (...)   2917         validated.
#    2918     """
# -> 2919     _check_feature_names(_estimator, X, reset=reset)
#    2920     tags = get_tags(_estimator)
#    2921     if y is None and tags.target_tags.required:
#
# File d:\MY PROJECTS\PANDAS_1\pandalearning\Lib\site-packages\sklearn\utils\validation.py:2777, in _check_feature_names(estimator, X, reset)
#    2774 if not missing_names and not unexpected_names:
#    2775     message += "Feature names must be in the same order as they were in fit.\n"
# -> 2777 raise ValueError(message)
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names seen at fit time, yet now missing:
# - Day
